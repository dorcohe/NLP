# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset,  DataLoader
import torch
from pytorch_transformers import *
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from pytorch_pretrained_bert.optimization import BertAdam, WarmupLinearSchedule
print(device)
import math
from scipy import spatial
from torch.autograd import Variable
# Out:
# cuda

# %%
import csv
SemEval_prefix = "SemEval_"
import pandas as pd
import numpy as np

class Parse_data:

    def  __init__ (self, file_path, testing_emotions_path):
        self.file_path = file_path
        self.testing_emotions_path = testing_emotions_path
        self.sem_eval2007_id_to_emotions = self.get_sem_eval2007_id_to_emotions()
        self.train_data()
        self.normalize_data()

    def train_data(self):
        data_from_file = pd.read_csv(self.file_path)
        boolean_indexes = data_from_file["id"].str.startswith(SemEval_prefix)
        self.train_instances = data_from_file[~boolean_indexes]
        self.test_instances = data_from_file[boolean_indexes]

        extra_column = [np.nan] * len(self.test_instances)
        self.test_instances.insert(5, "Categorial", extra_column, True)

        for index in self.sem_eval2007_id_to_emotions:
            value = self.sem_eval2007_id_to_emotions[index]
            self.test_instances.loc[self.test_instances.id == SemEval_prefix + str(index), "Categorial"] = [value]

        self.test_instances = self.test_instances.dropna(axis=0, how='any')

        train_instances = list(range(len(self.train_instances)))
        self.train_instances.reindex(train_instances)
        test_instances = list(range(len(self.test_instances)))
        self.test_instances.reindex(test_instances)


    def normalize_data(self):

        #Train
        #mean = self.train_instances.mean()
        #std = self.train_instances.std()
        maxi = self.train_instances.max()
        mini = self.train_instances.min()

        current_v = self.train_instances["V"]
        normalized_v = 2*(current_v - mini["V"]) / (maxi["V"]-mini["V"]) - 1
        self.train_instances["V"] = normalized_v

        current_a = self.train_instances["A"]
        normalized_a =2* (current_a - mini["A"]) / (maxi["A"]-mini["A"]) -1 
        self.train_instances["A"] = normalized_a
        
        current_d = self.train_instances["D"]
        normalized_d = 2*(current_d - mini["D"]) / (maxi["D"]-mini["D"]) -1
        self.train_instances["D"] = normalized_d
        
        #Test
        #mean = self.test_instances.mean()
        #std = self.test_instances.std()
        maxi = self.test_instances.max()
        mini = self.test_instances.min()


        current_v = self.test_instances["V"]
        normalized_v = 2*(current_v - mini["V"]) / (maxi["V"]-mini["V"]) - 1
        self.test_instances["V"] = normalized_v

        current_a = self.test_instances["A"]
        normalized_a = 2* (current_a - mini["A"]) / (maxi["A"]-mini["A"]) -1 
        self.test_instances["A"] = normalized_a

        current_d = self.test_instances["D"]
        normalized_d = 2*(current_d - mini["D"]) / (maxi["D"]-mini["D"]) -1
        self.test_instances["D"] = normalized_d


    def get_train_data(self):

        return self.train_instances


    def get_id_to_sentence_dict(self):
        sentences = {}
        with open(self.file_path, encoding='utf8') as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=',')
            line_count = 0

            for row in csv_reader:
                if line_count == 0:
                    line_count += 1
                else:
                    if line_count == 393:
                        line_count += 1
                    sentences.update({row[0]: row[1]})
                    line_count += 1
        return sentences

    def get_sem_eval2007_id_to_emotions(self):
        sentences = {}
        with open(self.testing_emotions_path) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=' ')

            # row is in the form: 0: id  1: anger 2: disgust 3: fear 4: joy 5 :sadness 6: surprise
            for row in csv_reader:
                instance = {
                    "id": row[0],
                    "anger": row[1],
                    "disgust": row[2],
                    "fear": row[3],
                    "joy": row[4],
                    "sadness": row[5],
                    "surprise": row[6]
                }
                sentences.update({row[0]: instance})

        return sentences


    def get_test_data(self):
        return self.test_instances

# reader_path = "./corpus/reader.csv"
# writer_path = "./corpus/writer.csv"
# raw_path = "./corpus/raw.csv"
# sem2007_paths = "./affectivetext_test.emotions.gold"
#
# moss = parse_data(reader_path, writer_path, raw_path, sem2007_paths)
#
# a = moss.get_train_data()
# b = moss.get_test_data()
# a = 3

# %%
class EmoBankDatabase(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, file_path, emotions_path, is_testing = False):
        parse_data_instance = Parse_data(file_path, emotions_path)
        if is_testing:
                self.par_data = parse_data_instance.get_test_data()
        else:
            self.par_data = parse_data_instance.get_train_data()

    def __len__(self):
        return len(self.par_data)

    def __getitem__(self, idx):
        item = self.par_data.iloc[idx]
        return item.text, torch.tensor([item.V, item.A, item.D])

# %%
class EmobankFineTuningModule(torch.nn.Module):
    def __init__(self, model_class):
        """
        In the constructor we instantiate two nn.Linear modules and assign them as
        member variables.
        """
        super(EmobankFineTuningModule, self).__init__()

        self.bert = model_class
        self.linear2 = torch.nn.Linear(768, 3)

    def forward(self, x):
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        x = [get_all_hidden_states(instance, self.bert) for instance in x]
        x = [self.linear2(instance.view(-1, 768)) for instance in x]
        x = [torch.mean(instance, dim=0) for instance in x]
        x = torch.stack(x, dim=0, out=None)
        return x

# %%
def get_all_hidden_states(x, model):
    all_hidden_states, all_attentions = model(x)[-2:]

    return all_hidden_states[0]


def get_all_hidden_states(x, model):
    all_hidden_states, all_attentions = model(x)[-2:]

    return all_hidden_states[0]



def Train_Net(my_net, trainloader, criterion, tokenizer):
    #optimizer = torch.optim.SGD(my_net.parameters(), lr=0.01, momentum=0.9)
    optimizer = BertAdam(my_net.parameters(), lr=0.001, schedule='warmup_linear', warmup=0.1, t_total=23000000)

    # training loop
    for epoch in range(1000):
        if epoch > 0:
            path = "/home/dor/modelCosinev7" + str(epoch+83)
            path2 = "/home/dor/tokinezerv" + str(epoch+83)
            torch.save(my_net, path) 
            torch.save(tokenizer, path2) 
            print(epoch_loss/len(trainloader))
        epoch_loss = 0.0
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            
            inputs, labels = data
                                    
            labels = labels.to(device)
            embedded_input = [torch.tensor([tokenizer.encode(text)]).to(device) for text in inputs]
                
            #flags = Variable(torch.ones(len(embedded_input))).to(device)

            

            # forward + backward + optimize
            outputs = my_net(embedded_input)
            #loss = torch.mean(torch.sqrt(torch.sum((outputs - labels) ** 2,  dim=1))).to(device) 
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # print statistics
            running_loss += loss.item()
            epoch_loss += loss.item()
            if i % 200 == 0 and i != 0:  # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 200))
                running_loss = 0.0
    return my_net

# %%
##########################################################################



########################################################################## Set  basic parameters

file_path = "/home/dor/emobank.csv"
emotions_path = "/home/dor/affectivetext_test.emotions.csv"



MODELS = [(BertModel,       BertTokenizer,      'bert-base-uncased'),
          (OpenAIGPTModel,  OpenAIGPTTokenizer, 'openai-gpt'),
          (GPT2Model,       GPT2Tokenizer,      'gpt2'),
          (TransfoXLModel,  TransfoXLTokenizer, 'transfo-xl-wt103'),
          (XLNetModel,      XLNetTokenizer,     'xlnet-base-cased'),
          (XLMModel,        XLMTokenizer,        'xlm-mlm-enfr-1024')]

model_class, tokenizer_class, pretrained_weights = MODELS[0]

# %%
def main():
    ## Dataset
    emobank_dataset_training = EmoBankDatabase(file_path , emotions_path)
    emobank_dataset_training
    

    dataloader_training = DataLoader(emobank_dataset_training, batch_size=4,
                            shuffle=True, num_workers=12)

    ## Model
    bert_model = model_class.from_pretrained(pretrained_weights,
                                        output_hidden_states=True,
                                        output_attentions=True)
    bert_model.to(device)
    criterion = nn.MSELoss()
    model = EmobankFineTuningModule(bert_model)
    model.to(device)
    tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
    model = torch.load("/home/dor/modelCosinev783").to(device)
    tokenizer = torch.load("/home/dor/tokinezerv83")
    model = Train_Net(model, dataloader_training, criterion, tokenizer)
    #model = torch.load("/home/dor/model3")
    
#     parse_data_instance = Parse_data(file_path, emotions_path)
#     test = parse_data_instance.get_test_data()
#     dataloader_testing = DataLoader(test, batch_size=4,
#                             shuffle=True, num_workers=4)
    
#     for i, data in enumerate(dataloader_testing, 0):
#         inputs, labels = data
#         labels = labels.to(device)
#         embedded_input = [torch.tensor([tokenizer.encode(text)]).to(device) for text in inputs]
#         outputs = model(embedded_input)
#         print(outputs)
#         print(labels)
#         loss = criterion(outputs, labels)
#         print(loss)
    
    
    
    
 



if __name__ == '__main__':
    main()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# [1,   201] loss: 0.006
# [1,   401] loss: 0.006
# [1,   601] loss: 0.007
# [1,   801] loss: 0.006
# [1,  1001] loss: 0.005
# [1,  1201] loss: 0.006
# [1,  1401] loss: 0.006
# [1,  1601] loss: 0.006
# [1,  1801] loss: 0.005
# [1,  2001] loss: 0.006
# [1,  2201] loss: 0.007
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type EmobankFineTuningModule. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 0.005957897496572423
# [2,   201] loss: 0.006
# [2,   401] loss: 0.006
# [2,   601] loss: 0.006
# [2,   801] loss: 0.006
# [2,  1001] loss: 0.005
# [2,  1201] loss: 0.006
# [2,  1401] loss: 0.006
# [2,  1601] loss: 0.005
# [2,  1801] loss: 0.006
# [2,  2001] loss: 0.006
# [2,  2201] loss: 0.006
# 0.005833949378989843
# [3,   201] loss: 0.006
# [3,   401] loss: 0.006
# [3,   601] loss: 0.006
# [3,   801] loss: 0.005
# [3,  1001] loss: 0.006
# [3,  1201] loss: 0.006
# [3,  1401] loss: 0.006
# [3,  1601] loss: 0.005
# [3,  1801] loss: 0.006
# [3,  2001] loss: 0.006
# [3,  2201] loss: 0.006
# 0.005758706089281995
# [4,   201] loss: 0.006
# [4,   401] loss: 0.006
# [4,   601] loss: 0.006
# [4,   801] loss: 0.005
# [4,  1001] loss: 0.006
# [4,  1201] loss: 0.005
# [4,  1401] loss: 0.006
# [4,  1601] loss: 0.005
# [4,  1801] loss: 0.006
# [4,  2001] loss: 0.005
# [4,  2201] loss: 0.006
# 0.00568214510836349
# [5,   201] loss: 0.006
# [5,   401] loss: 0.006
# [5,   601] loss: 0.005
# [5,   801] loss: 0.006
# [5,  1001] loss: 0.006
# [5,  1201] loss: 0.006
# [5,  1401] loss: 0.006
# [5,  1601] loss: 0.005
# [5,  1801] loss: 0.007
# [5,  2001] loss: 0.006
# [5,  2201] loss: 0.005
# 0.005650776938773273
# [6,   201] loss: 0.005
# [6,   401] loss: 0.006
# [6,   601] loss: 0.006
# [6,   801] loss: 0.005
# [6,  1001] loss: 0.006
# [6,  1201] loss: 0.005
# [6,  1401] loss: 0.006
# [6,  1601] loss: 0.006
# [6,  1801] loss: 0.006
# [6,  2001] loss: 0.006
# [6,  2201] loss: 0.006
# 0.005612293710427463
# [7,   201] loss: 0.006
# [7,   401] loss: 0.005
# [7,   601] loss: 0.007
# [7,   801] loss: 0.006
# [7,  1001] loss: 0.006
# [7,  1201] loss: 0.006
# [7,  1401] loss: 0.006
# [7,  1601] loss: 0.006
# [7,  1801] loss: 0.005
# [7,  2001] loss: 0.005
# [7,  2201] loss: 0.005
# 0.005593115607626854
# [8,   201] loss: 0.005
# [8,   401] loss: 0.006
# [8,   601] loss: 0.005
# [8,   801] loss: 0.006
# [8,  1001] loss: 0.005
# [8,  1201] loss: 0.006
# [8,  1401] loss: 0.005
# [8,  1601] loss: 0.006
# [8,  1801] loss: 0.005
# [8,  2001] loss: 0.006
# [8,  2201] loss: 0.006
# 0.005586391213118847
# [9,   201] loss: 0.005
# [9,   401] loss: 0.005
# [9,   601] loss: 0.005
# [9,   801] loss: 0.005
# [9,  1001] loss: 0.006
# [9,  1201] loss: 0.006
# [9,  1401] loss: 0.005
# [9,  1601] loss: 0.006
# [9,  1801] loss: 0.005
# [9,  2001] loss: 0.005
# [9,  2201] loss: 0.007
# 0.005561927909147401
# [10,   201] loss: 0.005
# [10,   401] loss: 0.006
# [10,   601] loss: 0.006
# [10,   801] loss: 0.005
# [10,  1001] loss: 0.005
# [10,  1201] loss: 0.005
# [10,  1401] loss: 0.006
# [10,  1601] loss: 0.006
# [10,  1801] loss: 0.006
# [10,  2001] loss: 0.006
# [10,  2201] loss: 0.005
# 0.005555096264047185
# [11,   201] loss: 0.005
# [11,   401] loss: 0.005
# [11,   601] loss: 0.005
# [11,   801] loss: 0.005
# [11,  1001] loss: 0.006
# [11,  1201] loss: 0.006
# [11,  1401] loss: 0.006
# [11,  1601] loss: 0.006
# [11,  1801] loss: 0.005
# [11,  2001] loss: 0.006
# [11,  2201] loss: 0.006
# 0.0055372499615625355
# [12,   201] loss: 0.005
# [12,   401] loss: 0.006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e70d27368d6f> in <module>()
#      45
#      46 if __name__ == '__main__':
# ---> 47     main()
#
# <ipython-input-8-e70d27368d6f> in main()
#      19     model = torch.load("/home/dor/modelCosinev783").to(device)
#      20     tokenizer = torch.load("/home/dor/tokinezerv83")
# ---> 21     model = Train_Net(model, dataloader_training, criterion, tokenizer)
#      22     #model = torch.load("/home/dor/model3")
#      23
#
# <ipython-input-6-c1390090f447> in Train_Net(my_net, trainloader, criterion, tokenizer)
#      39
#      40             # forward + backward + optimize
# ---> 41             outputs = my_net(embedded_input)
#      42             #loss = torch.mean(torch.sqrt(torch.sum((outputs - labels) ** 2,  dim=1))).to(device)
#      43             loss = criterion(outputs, labels)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-4-b8a339ac9c9a> in forward(self, x)
#      16         well as arbitrary operators on Tensors.
#      17         """
# ---> 18         x = [get_all_hidden_states(instance, self.bert) for instance in x]
#      19         x = [self.linear2(instance.view(-1, 768)) for instance in x]
#      20         x = [torch.mean(instance, dim=0) for instance in x]
#
# <ipython-input-4-b8a339ac9c9a> in <listcomp>(.0)
#      16         well as arbitrary operators on Tensors.
#      17         """
# ---> 18         x = [get_all_hidden_states(instance, self.bert) for instance in x]
#      19         x = [self.linear2(instance.view(-1, 768)) for instance in x]
#      20         x = [torch.mean(instance, dim=0) for instance in x]
#
# <ipython-input-6-c1390090f447> in get_all_hidden_states(x, model)
#       6
#       7 def get_all_hidden_states(x, model):
# ----> 8     all_hidden_states, all_attentions = model(x)[-2:]
#       9
#      10     return all_hidden_states[0]
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pytorch_transformers/modeling_bert.py in forward(self, input_ids, token_type_ids, attention_mask, position_ids, head_mask)
#     713         encoder_outputs = self.encoder(embedding_output,
#     714                                        extended_attention_mask,
# --> 715                                        head_mask=head_mask)
#     716         sequence_output = encoder_outputs[0]
#     717         pooled_output = self.pooler(sequence_output)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pytorch_transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     435                 all_hidden_states = all_hidden_states + (hidden_states,)
#     436
# --> 437             layer_outputs = layer_module(hidden_states, attention_mask, head_mask[i])
#     438             hidden_states = layer_outputs[0]
#     439
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pytorch_transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     413
#     414     def forward(self, hidden_states, attention_mask, head_mask=None):
# --> 415         attention_outputs = self.attention(hidden_states, attention_mask, head_mask)
#     416         attention_output = attention_outputs[0]
#     417         intermediate_output = self.intermediate(attention_output)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pytorch_transformers/modeling_bert.py in forward(self, input_tensor, attention_mask, head_mask)
#     370
#     371     def forward(self, input_tensor, attention_mask, head_mask=None):
# --> 372         self_outputs = self.self(input_tensor, attention_mask, head_mask)
#     373         attention_output = self.output(self_outputs[0], input_tensor)
#     374         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/pytorch_transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     297
#     298     def forward(self, hidden_states, attention_mask, head_mask=None):
# --> 299         mixed_query_layer = self.query(hidden_states)
#     300         mixed_key_layer = self.key(hidden_states)
#     301         mixed_value_layer = self.value(hidden_states)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      65     @weak_script_method
#      66     def forward(self, input):
# ---> 67         return F.linear(input, self.weight, self.bias)
#      68
#      69     def extra_repr(self):
#
# /anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1352         ret = torch.addmm(torch.jit._unwrap_optional(bias), input, weight.t())
#    1353     else:
# -> 1354         output = input.matmul(weight.t())
#    1355         if bias is not None:
#    1356             output += torch.jit._unwrap_optional(bias)
#
# KeyboardInterrupt:

# %%
model = torch.load("/home/dor/modelCosinev794")
tokenizer = torch.load("/home/dor/tokinezerv94")

# %%
emobank_dataset_testing = EmoBankDatabase(file_path , emotions_path, True)
dataloader_testing = DataLoader(emobank_dataset_testing, batch_size=1,
                        shuffle=True, num_workers=4)

number_of_instances = len(emobank_dataset_testing)
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
criterion = nn.MSELoss()

# %%
sum_loss = 0
for i, data in enumerate(dataloader_testing, 0):
        # get the inputs
        inputs, labels = data
        
        labels = labels.to(device)
        embedded_input = [torch.tensor([tokenizer.encode(text)]).to(device) for text in inputs]
        model.eval()
        outputs = model(embedded_input)
        #flags = Variable(torch.ones(len(embedded_input))).to(device)
        loss = criterion(outputs, labels)
        print("outpus" + str(outputs))
        print("labels" + str(labels))
        print(torch.sqrt(torch.sum((outputs - labels) ** 2,  dim=1)))
        print(torch.mean(torch.sqrt(torch.sum((outputs - labels) ** 2,  dim=1))))
        print("loss" + str(loss))
        sum_loss = sum_loss + loss.item()
print("finished")
# Out:
# outpustensor([[-0.3349, -0.1034,  0.0812]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5263,  0.0466, -0.1083]], device='cuda:0')
# tensor([0.3083], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3083, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0317, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1666, 0.1396, 0.1136]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.1654, 0.3161, 0.5669]], device='cuda:0')
# tensor([0.4864], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4864, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0789, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.2572, 0.2233, 0.3407]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2481, -0.0363,  0.1465]], device='cuda:0')
# tensor([0.3243], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3243, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0351, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1793, -0.8314, -0.4161]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.3008, -0.0570,  0.4013]], device='cuda:0')
# tensor([1.2241], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.2241, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4994, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.4077, -0.3318, -0.1969]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1053, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.4625], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4625, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0713, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1069, -0.0475,  0.0418]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.4511, 0.0466, 0.2739]], device='cuda:0')
# tensor([0.4257], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4257, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0604, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7031, -0.3386, -0.2465]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.1606,  0.1465]], device='cuda:0')
# tensor([0.7618], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7618, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1935, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1031, -0.3724, -0.1336]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606, -0.1083]], device='cuda:0')
# tensor([0.2369], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2369, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.4580, 0.5442, 0.6022]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2256, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.8116], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8116, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2195, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3853, -0.0564,  0.1643]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1504, -0.0570,  0.2739]], device='cuda:0')
# tensor([0.2592], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2592, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1608, 0.0739, 0.0249]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.3679,  0.0191]], device='cuda:0')
# tensor([0.4702], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4702, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0737, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.3296, 0.0320, 0.1825]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511, -0.3679,  0.0191]], device='cuda:0')
# tensor([0.8922], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8922, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2654, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2150,  0.1146,  0.1725]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.2642,  0.0191]], device='cuda:0')
# tensor([0.4176], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4176, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0581, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3314,  0.1707, -0.4708]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0827, -0.1503,  0.2866]], device='cuda:0')
# tensor([0.9210], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9210, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2827, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1182, -0.2117,  0.0345]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0827, -0.2642,  0.4268]], device='cuda:0')
# tensor([0.3973], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3973, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0526, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1232, -0.4659, -0.0706]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642, -0.1083]], device='cuda:0')
# tensor([0.2070], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2070, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1600, -0.3923,  0.1592]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0902, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.1464], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1464, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1692,  0.4667,  0.2834]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6015,  0.2539,  0.4013]], device='cuda:0')
# tensor([0.4961], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4961, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0820, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.8049,  0.3924,  0.2922]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4662, -0.1399,  0.6306]], device='cuda:0')
# tensor([0.7159], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7159, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1709, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1495,  0.0286, -0.0053]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.2105, 0.0363, 0.5159]], device='cuda:0')
# tensor([0.6336], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6336, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1338, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2390, -0.4325, -0.0715]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2256, -0.0570,  0.4013]], device='cuda:0')
# tensor([0.6039], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6039, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1216, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1043,  0.2110,  0.0488]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4715,  0.0191]], device='cuda:0')
# tensor([0.6910], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6910, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1592, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.6378, 0.4578, 0.0998]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2481, -0.1503,  0.4268]], device='cuda:0')
# tensor([0.7927], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7927, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2095, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3315,  0.0361, -0.3092]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1504, -0.3679,  0.1465]], device='cuda:0')
# tensor([0.6353], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6353, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1345, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1335, -0.0782, -0.2152]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6692, -0.0363, -0.2739]], device='cuda:0')
# tensor([0.5405], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5405, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0974, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1059,  0.0288, -0.0937]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1353, -0.3575, -0.0828]], device='cuda:0')
# tensor([0.3876], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3876, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0501, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.3480, 0.0121, 0.3514]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4404,  0.1465]], device='cuda:0')
# tensor([0.6065], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6065, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1226, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1405, -0.1407,  0.2444]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.1399,  0.2994]], device='cuda:0')
# tensor([0.2418], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2418, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3144, -0.6253, -0.0424]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.2256, 0.3575, 0.5287]], device='cuda:0')
# tensor([1.2584], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.2584, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.5279, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-1.1803,  0.4880,  0.1497]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4737, -0.2642, -0.0828]], device='cuda:0')
# tensor([1.0580], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0580, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3731, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.7967, -0.5390, -0.2391]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5263, -0.1606, -0.3631]], device='cuda:0')
# tensor([1.3816], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.3816, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.6363, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.6042,  0.2153, -0.4106]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.1606,  0.0191]], device='cuda:0')
# tensor([0.6466], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6466, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1394, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5508,  0.2244, -0.1524]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.7519, -0.1192, -0.0318]], device='cuda:0')
# tensor([0.4159], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4159, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0577, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2492, -0.1007, -0.2685]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5263,  0.1503, -0.4904]], device='cuda:0')
# tensor([0.4348], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4348, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0630, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.5886, 0.3372, 0.3798]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3233, -0.4093,  0.1465]], device='cuda:0')
# tensor([1.2014], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.2014, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4811, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.6056, -0.1527,  0.3653]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.3679,  0.4013]], device='cuda:0')
# tensor([0.7868], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7868, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2064, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1963, -0.1326, -0.3595]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1654, -0.0363,  0.4268]], device='cuda:0')
# tensor([0.7927], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7927, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2095, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0205, -0.0378, -0.1710]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.0570,  0.4013]], device='cuda:0')
# tensor([0.5730], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5730, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1094, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.5501, 0.0652, 0.0429]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.6379], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6379, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1356, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1131, -0.0821, -0.3165]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.0570,  0.2739]], device='cuda:0')
# tensor([0.6202], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6202, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1282, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1040,  0.1615,  0.1480]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.0570, -0.1083]], device='cuda:0')
# tensor([0.3580], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3580, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0427, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.5602, -0.6739,  0.1999]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.6710], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6710, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1501, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3721, -0.0730, -0.2087]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3759, 0.1192, 0.4650]], device='cuda:0')
# tensor([1.0248], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0248, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3501, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3808, -0.1376,  0.0836]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.3759, -0.0570,  0.4013]], device='cuda:0')
# tensor([0.3278], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3278, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0358, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7587,  0.1957,  0.1914]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008,  0.0466,  0.2739]], device='cuda:0')
# tensor([0.4886], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4886, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0796, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4817, -0.2564,  0.2960]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0902, -0.0052,  0.1465]], device='cuda:0')
# tensor([0.4886], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4886, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0796, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2037, -0.0555,  0.2467]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3008, 0.0466, 0.2739]], device='cuda:0')
# tensor([0.1435], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1435, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.4804, 0.1194, 0.2327]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1053, -0.2642,  0.3248]], device='cuda:0')
# tensor([0.5444], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5444, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0988, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2250, -0.5714, -0.1619]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0902, -0.0052,  0.1465]], device='cuda:0')
# tensor([0.7177], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7177, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1717, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1735, 0.2032, 0.2447]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3759, 0.0466, 0.5287]], device='cuda:0')
# tensor([0.3823], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3823, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0487, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0267, -0.0740, -0.4785]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.3679,  0.0191]], device='cuda:0')
# tensor([0.6752], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6752, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1520, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1222, -0.1334,  0.1930]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0827,  0.0777,  0.7070]], device='cuda:0')
# tensor([0.5922], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5922, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1169, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2655,  0.0069,  0.2065]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1880, -0.6580, -0.3248]], device='cuda:0')
# tensor([0.8547], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8547, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2435, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0739,  0.0607, -0.1848]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.6788, -0.1083]], device='cuda:0')
# tensor([0.7471], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7471, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1861, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.0634, 0.1192, 0.5752]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.9023,  0.3575, -0.2357]], device='cuda:0')
# tensor([1.2833], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.2833, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.5489, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4456,  0.1160,  0.0030]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.5038, 0.0777, 0.1465]], device='cuda:0')
# tensor([0.9609], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9609, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3078, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1895, -0.4963,  0.1095]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4404,  0.1465]], device='cuda:0')
# tensor([0.2010], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2010, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3012, -0.6476, -0.4225]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2857, -0.1295,  0.2994]], device='cuda:0')
# tensor([0.8887], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8887, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2633, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2747, -0.2144,  0.3932]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1353, -0.3575,  0.2611]], device='cuda:0')
# tensor([0.2394], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2394, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1031, -0.0212, -0.4222]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.1504, 0.0466, 0.5287]], device='cuda:0')
# tensor([0.9864], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9864, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3244, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1721, -0.3202,  0.1732]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6767, -0.1606, -0.4904]], device='cuda:0')
# tensor([0.8488], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8488, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2402, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.5840, 0.0404, 0.5331]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2030, -0.0777,  0.3758]], device='cuda:0')
# tensor([0.4288], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4288, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0613, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0361, -0.0718,  0.1890]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.0570,  0.6561]], device='cuda:0')
# tensor([0.4687], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4687, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0732, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5275,  0.2545, -0.2093]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.1606, -0.4904]], device='cuda:0')
# tensor([0.5238], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5238, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0914, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1773,  0.7174, -0.3488]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1880, -0.2642,  0.1465]], device='cuda:0')
# tensor([1.0996], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0996, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4030, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1987, -0.1641,  0.2712]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.1665], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1665, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.9328, -0.2565,  0.1975]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.8090], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8090, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2182, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1219,  0.1401, -0.0616]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.5751,  0.0191]], device='cuda:0')
# tensor([0.7300], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7300, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1776, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7449, -0.3967, -0.2493]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5338, -0.1192, -0.2229]], device='cuda:0')
# tensor([0.3497], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3497, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0408, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5236,  0.1493, -0.0893]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6015,  0.0466,  0.0191]], device='cuda:0')
# tensor([0.1684], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1684, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0187, -0.0915,  0.2371]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.1504, 0.0466, 0.0191]], device='cuda:0')
# tensor([0.3086], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3086, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0317, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1525, -0.6681, -0.5035]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1053, -0.2642,  0.3248]], device='cuda:0')
# tensor([0.9228], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9228, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2838, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3812, -0.7077, -0.5672]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0827, -0.3782,  0.2866]], device='cuda:0')
# tensor([0.9627], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9627, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3089, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0298, -0.3110,  0.1128]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.4651], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4651, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0721, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3001, -0.2997,  0.4772]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.4480], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4480, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0669, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2694,  0.4003,  0.0604]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.3679,  0.4013]], device='cuda:0')
# tensor([0.8626], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8626, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2480, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.4900, -0.0243,  0.0330]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.1606,  0.0191]], device='cuda:0')
# tensor([0.8026], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8026, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2147, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.5307, -0.2068,  0.1894]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.4668], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4668, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0726, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0135, -0.3967,  0.0382]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4508,  0.2611]], device='cuda:0')
# tensor([0.2298], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2298, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2145, -0.3503,  0.0553]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.3679,  0.1465]], device='cuda:0')
# tensor([0.2337], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2337, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3165,  0.1681, -0.1781]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1504, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.4285], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4285, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0612, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1453, -0.1763, -0.0313]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0677, -0.1710,  0.3758]], device='cuda:0')
# tensor([0.4145], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4145, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0573, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.7253, -0.5014,  0.1269]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.1504, 0.0466, 0.1465]], device='cuda:0')
# tensor([0.7946], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7946, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2104, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3630, -0.0775, -0.0065]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.4715,  0.0191]], device='cuda:0')
# tensor([0.5898], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5898, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1160, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4474,  0.1433,  0.6422]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6767,  0.2539,  0.0191]], device='cuda:0')
# tensor([0.6731], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6731, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1510, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4388,  1.6846,  0.4904]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6015,  0.2539,  0.5287]], device='cuda:0')
# tensor([1.4404], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.4404, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.6916, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2112, -0.1102, -0.4046]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.3631]], device='cuda:0')
# tensor([0.8110], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8110, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2192, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0945, -0.0781, -0.1195]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606, -0.2357]], device='cuda:0')
# tensor([0.1710], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1710, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1470, -0.2482, -0.0608]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.4562], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4562, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0694, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0053, -0.2792,  0.2317]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.0867], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.0867, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1680, -0.2300,  0.2631]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.1606,  0.4013]], device='cuda:0')
# tensor([0.2882], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2882, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0277, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2981, -0.0229, -0.1755]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2857, -0.0052,  0.1465]], device='cuda:0')
# tensor([0.6669], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6669, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1483, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5891,  0.8771, -0.5940]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.0570,  0.0191]], device='cuda:0')
# tensor([1.1749], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1749, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4602, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1977, -0.6879, -0.1886]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0902, -0.3886,  0.2994]], device='cuda:0')
# tensor([0.5824], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5824, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1131, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3493, -0.3390,  0.0756]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759,  0.0466, -0.1083]], device='cuda:0')
# tensor([0.8417], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8417, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2362, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0584, -0.0344,  0.1535]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1654, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.2536], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2536, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.6029, -0.0613,  0.1067]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3308, 0.0777, 0.2866]], device='cuda:0')
# tensor([0.3546], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3546, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0419, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1501,  0.1241,  0.0450]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.4753], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4753, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0753, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3315, -0.4352, -0.0041]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.0752, 0.0466, 0.5287]], device='cuda:0')
# tensor([0.8255], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8255, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2271, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3290, -0.3310, -0.3021]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0827, -0.1503,  0.1465]], device='cuda:0')
# tensor([0.6351], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6351, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1345, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3126, -0.1799,  0.3147]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2256, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.2074], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2074, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.4715,  0.4130, -0.0493]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.0881, -0.0701]], device='cuda:0')
# tensor([0.9847], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9847, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3232, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3571, -0.0550,  0.1998]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4715, -0.1083]], device='cuda:0')
# tensor([0.6292], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6292, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1320, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1023,  0.3150,  0.0423]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5639,  0.1295, -0.0064]], device='cuda:0')
# tensor([0.4999], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4999, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0833, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.5598, -0.0927,  0.1739]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1880, -0.2642,  0.4650]], device='cuda:0')
# tensor([0.5024], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5024, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0841, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0739, -0.0045, -0.2748]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.5752], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5752, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1103, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5372, -0.1382, -0.1646]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.0570,  0.2739]], device='cuda:0')
# tensor([0.5440], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5440, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0987, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1991,  0.1479,  0.6772]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.0052,  0.1465]], device='cuda:0')
# tensor([0.5800], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5800, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1121, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2411, -0.0135, -0.0889]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.5026], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5026, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0842, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4275, -0.4423, -0.0567]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511,  0.0466,  0.0191]], device='cuda:0')
# tensor([0.4953], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4953, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0818, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.6543,  0.7808,  0.5235]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3308, -0.0363,  0.0064]], device='cuda:0')
# tensor([1.0196], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0196, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3465, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4743,  0.1490, -0.5812]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511,  0.1503, -0.2357]], device='cuda:0')
# tensor([0.3463], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3463, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0400, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.0739, 0.2516, 0.1782]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.1606, -0.1083]], device='cuda:0')
# tensor([0.6740], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6740, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1514, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3754, -0.7806, -0.4035]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1399,  0.1465]], device='cuda:0')
# tensor([0.9241], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9241, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2846, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0078, -0.2845,  0.0150]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.0052,  0.2994]], device='cuda:0')
# tensor([0.3987], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3987, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0530, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3172, -0.1323, -0.0365]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.2642,  0.0191]], device='cuda:0')
# tensor([0.1548], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1548, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2374, -0.7801, -0.0470]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.3631]], device='cuda:0')
# tensor([0.7004], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7004, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1635, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1075, -0.1846,  0.2382]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.3308, -0.1503,  0.5669]], device='cuda:0')
# tensor([0.3988], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3988, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0530, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3911,  0.0105,  0.1633]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.6788,  0.4013]], device='cuda:0')
# tensor([0.7679], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7679, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1965, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1244, -0.0002, -0.0910]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.1606,  0.4013]], device='cuda:0')
# tensor([0.5201], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5201, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0902, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1108, -0.6082, -0.3127]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511,  0.0466, -0.1083]], device='cuda:0')
# tensor([0.7658], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7658, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1955, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1494, 0.2227, 0.1663]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.7519, -0.0052,  0.7834]], device='cuda:0')
# tensor([1.1158], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1158, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4150, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3295, -0.1174, -0.2520]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.5746], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5746, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1101, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1777,  0.2320,  0.5940]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.6914], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6914, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1594, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.6624, -0.0310,  0.2272]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3233, 0.0363, 0.8726]], device='cuda:0')
# tensor([1.1802], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1802, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4643, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0251, -0.0861,  0.0768]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.2703], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2703, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2926,  0.3628,  0.7202]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2180,  0.0363,  0.3248]], device='cuda:0')
# tensor([0.5182], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5182, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0895, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0275, -0.2484,  0.0626]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.6015, 0.0466, 0.4013]], device='cuda:0')
# tensor([0.7729], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7729, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1991, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0618, -0.5257,  0.1414]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2180, -0.8549,  0.1465]], device='cuda:0')
# tensor([0.3645], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3645, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0443, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0648, -0.4699,  0.0402]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.2468], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2468, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1869, 0.2524, 0.0918]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.5801], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5801, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1122, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3390,  0.0166, -0.2516]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.2642,  0.0191]], device='cuda:0')
# tensor([0.3919], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3919, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0512, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3176, -0.5986, -0.1953]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.4511, -0.0570,  0.4013]], device='cuda:0')
# tensor([1.1137], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1137, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4134, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1070, -0.2926,  0.1445]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.2454], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2454, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2894,  0.0847, -0.0473]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.2642,  0.5287]], device='cuda:0')
# tensor([0.7658], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7658, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1955, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2559,  0.4322,  0.3447]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4662, -0.2642, -0.1720]], device='cuda:0')
# tensor([0.8923], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8923, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2654, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5636, -0.0498, -0.3469]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.0752, 0.0466, 0.2739]], device='cuda:0')
# tensor([0.8959], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8959, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2676, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0025,  0.0999,  0.1183]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3308, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.4911], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4911, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0804, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0538,  0.0746, -0.4411]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.7546], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7546, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1898, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7844,  0.0797,  0.1012]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.8271, -0.0570, -0.2357]], device='cuda:0')
# tensor([0.3660], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3660, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0447, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1875, -0.1844,  0.1634]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.1606,  0.2739]], device='cuda:0')
# tensor([0.1600], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1600, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1217, -0.2926,  0.2170]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.1606,  0.0191]], device='cuda:0')
# tensor([0.4209], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4209, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0591, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3759, -0.1389,  0.0822]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6165,  0.2124, -0.0828]], device='cuda:0')
# tensor([0.4567], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4567, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0695, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3019, -0.0422, -0.0899]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3008, 0.0466, 0.2739]], device='cuda:0')
# tensor([0.7095], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7095, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1678, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.4982, -0.9307,  0.4025]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.4715,  0.1465]], device='cuda:0')
# tensor([0.7243], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7243, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1749, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0956, -0.4014,  0.1980]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1880, -0.9067, -0.0064]], device='cuda:0')
# tensor([0.5528], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5528, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1019, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3946,  0.0881, -0.1672]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.5865,  0.3161,  0.0064]], device='cuda:0')
# tensor([0.3448], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3448, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0396, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.4838, -0.0063, -0.0479]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4286,  0.3264, -0.5796]], device='cuda:0')
# tensor([0.6297], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6297, device='cuda:0', grad_fn=<MeanBackward1>)
# ...
# losstensor(0.1324, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0430, -0.1456,  0.5200]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.4370], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4370, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0637, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.2106, -0.2893,  0.1228]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6617, -0.1399,  0.2994]], device='cuda:0')
# tensor([0.9024], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9024, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2715, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.2019, 0.2246, 0.1764]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.5263, -0.0570,  0.2739]], device='cuda:0')
# tensor([0.4405], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4405, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0647, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1011, -0.4442,  0.3049]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.3759, 0.1503, 0.4013]], device='cuda:0')
# tensor([0.6620], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6620, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1461, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1010,  0.3306,  0.0914]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.4511, 0.4611, 0.6561]], device='cuda:0')
# tensor([0.8005], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8005, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2136, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0583, -0.6230,  0.2752]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511, -0.2642,  0.0191]], device='cuda:0')
# tensor([0.6736], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6736, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1513, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0828, -0.6686, -0.4765]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1353, -0.5440,  0.2611]], device='cuda:0')
# tensor([0.7499], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7499, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1875, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.0420, 0.0097, 0.0238]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.1053, 0.0363, 0.1465]], device='cuda:0')
# tensor([0.1406], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1406, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0784, -0.1021,  0.1450]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1053, -0.1192,  0.3248]], device='cuda:0')
# tensor([0.1826], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1826, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3827, -0.1303, -0.2411]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6692, -0.2642,  0.2866]], device='cuda:0')
# tensor([0.6152], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6152, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1262, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-1.3747, -0.1309, -0.9844]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.8346, -0.3782, -0.1338]], device='cuda:0')
# tensor([1.0376], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0376, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3589, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1518, 0.3519, 0.1636]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.3679,  0.0191]], device='cuda:0')
# tensor([0.7939], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7939, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2101, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0207, -0.3549,  0.2113]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2256, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.2703], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2703, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1276, 0.3491, 0.0549]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.2481, 0.1917, 0.2866]], device='cuda:0')
# tensor([0.3050], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3050, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0310, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.0621, 0.1211, 0.3944]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642, -0.1083]], device='cuda:0')
# tensor([0.6680], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6680, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1488, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.4300, -0.3365,  0.1815]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.5263, -0.2642,  0.2739]], device='cuda:0')
# tensor([0.1518], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1518, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1069, -0.2683, -0.3990]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.7485], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7485, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1867, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0504, -0.1315, -0.1046]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752,  0.0466,  0.1465]], device='cuda:0')
# tensor([0.3089], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3089, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0318, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0470, -0.1251,  0.0164]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606,  0.1465]], device='cuda:0')
# tensor([0.1428], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1428, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.6252, -0.3633,  0.1589]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1053, -0.2642, -0.0318]], device='cuda:0')
# tensor([0.7614], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7614, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1932, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.2567, 0.1894, 0.1825]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.2256, -0.2642,  0.0191]], device='cuda:0')
# tensor([0.4831], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4831, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0778, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.3286,  0.1800, -0.3111]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.7175], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7175, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1716, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.9087, 0.0677, 0.5563]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.3679,  0.1465]], device='cuda:0')
# tensor([1.0878], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.0878, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3944, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2500,  0.0169, -0.1818]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2857, -0.1399,  0.2994]], device='cuda:0')
# tensor([0.5073], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5073, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0858, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3087,  0.2459,  0.0372]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.1504, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.8840], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8840, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2605, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7440, -1.1739, -1.1062]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.7824, -0.0191]], device='cuda:0')
# tensor([1.3743], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.3743, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.6295, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.0480, -0.2047,  0.0571]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.4715,  0.2739]], device='cuda:0')
# tensor([0.3449], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3449, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0396, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-1.2198, -0.3735, -0.8452]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4135, -0.5440,  0.0318]], device='cuda:0')
# tensor([1.2034], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.2034, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4828, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0180,  0.1148, -0.1323]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.3679,  0.0191]], device='cuda:0')
# tensor([0.5468], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5468, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0997, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.1541, -0.1501,  0.4141]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.2642, -0.1083]], device='cuda:0')
# tensor([0.5818], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5818, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1128, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.1409, -0.2346, -0.0891]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0752, -0.1606,  0.1465]], device='cuda:0')
# tensor([0.2555], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2555, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.9932,  0.0186, -0.1139]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3759, -0.0570,  0.0191]], device='cuda:0')
# tensor([0.6359], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6359, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1348, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.2092, 0.5452, 0.1201]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.7519, -0.0570, -0.2357]], device='cuda:0')
# tensor([1.1887], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1887, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4710, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0693, -0.0041, -0.0868]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511, -0.2642, -0.3631]], device='cuda:0')
# tensor([0.5383], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5383, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0966, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5708,  0.0616, -0.1730]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511,  0.0466, -0.1083]], device='cuda:0')
# tensor([0.1369], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.1369, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.6118, -0.0847, -0.1055]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1880, -0.5233,  0.3121]], device='cuda:0')
# tensor([0.7392], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.7392, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1821, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.2391, 0.1879, 0.1495]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.0752, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.3984], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3984, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0529, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.5627,  0.6722,  0.2312]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.6015, -0.4715,  0.4013]], device='cuda:0')
# tensor([1.1569], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.1569, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.4462, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.2249,  0.2792,  0.1303]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.2642,  0.0064]], device='cuda:0')
# tensor([0.6011], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6011, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1204, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3843,  0.0070,  0.0952]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.1606,  0.4013]], device='cuda:0')
# tensor([0.4201], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4201, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0588, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.5836, -0.0938,  0.1261]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[0.5338, 0.0363, 0.5159]], device='cuda:0')
# tensor([0.4140], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.4140, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0571, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[ 0.9698, -0.4786,  0.6869]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.3008, -0.2642,  0.2739]], device='cuda:0')
# tensor([1.3531], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(1.3531, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.6103, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0947, -0.2742, -0.1611]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642,  0.1465]], device='cuda:0')
# tensor([0.3128], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.3128, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0326, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3030, -0.2606, -0.0108]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2180, -0.2642, -0.2229]], device='cuda:0')
# tensor([0.2286], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.2286, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[0.1448, 0.0161, 0.1037]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2256, -0.3679, -0.1083]], device='cuda:0')
# tensor([0.5740], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5740, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1098, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.0454,  0.0504,  0.3557]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.2180, -0.2642, -0.4013]], device='cuda:0')
# tensor([0.8377], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.8377, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.2339, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.3933,  0.4845, -0.1777]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[-0.4511, -0.0570,  0.1465]], device='cuda:0')
# tensor([0.6337], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.6337, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.1339, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-3.0491e-01, -4.3314e-05, -2.6422e-02]], device='cuda:0',
#        grad_fn=<StackBackward>)
# labelstensor([[-0.1504, -0.2642,  0.4013]], device='cuda:0')
# tensor([0.5259], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.5259, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.0922, device='cuda:0', grad_fn=<MseLossBackward>)
# outpustensor([[-0.7367, -0.3923, -0.2196]], device='cuda:0', grad_fn=<StackBackward>)
# labelstensor([[ 0.0000, -0.1606,  0.4013]], device='cuda:0')
# tensor([0.9909], device='cuda:0', grad_fn=<SqrtBackward>)
# tensor(0.9909, device='cuda:0', grad_fn=<MeanBackward1>)
# losstensor(0.3273, device='cuda:0', grad_fn=<MseLossBackward>)
# finished

# %%
print(i)
print ("loss = " + str (sum_loss / i))
# Out:
# 949
# loss = 0.15924595648640458

# %%
categories_vad = {
    "joy":{
        "v":0.76,
        "a":0.48,
        "d":0.35
    },
    "anger":{
        "v":-0.51,
        "a":0.59,
        "d":0.25
    },
      "sadness":{
        "v":-0.63,
        "a":-0.27,
        "d":-0.33
    },
      "fear":{
        "v":-0.64,
        "a":0.6,
        "d":-0.43
    },
      "disgust":{
        "v":-0.6,
        "a":0.35,
        "d":0.11
    },
    "surprise":{
        "v":0.4,
        "a":0.67,
        "d":-0.13
    }
}


index_to_catogory = {
    0 : "joy",
    1 : "anger",
    2 : "sadness",
    3 : "fear",
    4 : "disgust",
    5 : "surprise",
}

category_to_index = ["joy", "anger", "sadness", "fear", "disgust", "surprise"]

# %%
def get_category(model_output):
    model_output = model_output[0]
    categories_distance = []
    for i, category in enumerate(category_to_index):
        # index: 0:V, 1:A, 2:D
        current_category_vad = categories_vad[category]
        a = np.empty(3)
        a[0] = current_category_vad["v"]
        a[1] = current_category_vad["a"]
        a[2] = current_category_vad["d"]
        distance_from_category = get_distance(a,model_output.to("cpu").detach().numpy())
        categories_distance.append(distance_from_category)
#     print(category_to_index)
#     print(categories_distance)
    return index_to_catogory[categories_distance.index(min(categories_distance))]

# %%
def get_distance(a, b):
    return (np.square(a - b)).mean(axis=None)
#math.sqrt((current_category_vad["v"] - model_output[0])**2 + (current_category_vad["a"] - model_output[1])**2 + (current_category_vad["d"] - model_output[2])**2)

# %%
def get_instance_category(test_instance):
    max_value_first = -1
    max_value_second = -1
    max_category_first = "moss"
    max_category_second = "moss"
    instance_categories = test_instance["Categorial"]
    for category in instance_categories:
        if float(instance_categories[category]) > max_value_second and category != "id":
            max_value_first = max_value_second
            max_value_second = float(instance_categories[category])
            max_category_first = max_category_second
            max_category_second = category
    return [max_category_first]

# %%
parse_data_instance = Parse_data(file_path, emotions_path)
test = parse_data_instance.get_test_data()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
total_count = 0
correct_count = 0
    
for i, test_insance in test.iterrows():
    text = test_insance["text"]
    embeded_text = torch.tensor([tokenizer.encode(text)]).to(device)
    outputs = model([embeded_text])

#     print(test_insance)
#     print("item" + str(test_insance))
#    outputs = [torch.tensor([test_insance.V, test_insance.A, test_insance.D])]

#     print("outputs: " + str(outputs))

    category = get_category(outputs)
    instance_actual_category = get_instance_category(test_insance)

#     print("actual: " + instance_actual_category + ", category:" + str(category))
#     if category == instance_actual_category:
    if category in instance_actual_category:
        correct_count += 1 
    total_count += 1

# %%
print("correctness: " + str(correct_count / total_count))
# Out:
# correctness: 0.14105263157894737
